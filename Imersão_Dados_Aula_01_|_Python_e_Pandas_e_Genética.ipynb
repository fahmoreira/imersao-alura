# %% [markdown]
# <a href="https://colab.research.google.com/github/fahmoreira/imersao-alura-3/blob/main/Imers%C3%A3o_Dados_Aula_01_%7C_Python_e_Pandas_e_Gen%C3%A9tica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imersão de Dados Alura

# %%
# Carregar os dados via URL
# No github abra o zip e em cima da opção "view raw" clique com o botão direito e copiar.
import pandas as pd
dados_url = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(dados_url, compression = 'zip')
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# *Informações extras*
# * Cada id trata-se de uma célula tratada.
# * Cada célula tem a capacidade **limitada** de multiplicação, porém uma **célula cancerigena tem capacidade ilimitada**, portanto, são cancerígenas.

# %%
# Função para retornar linhas x colunas
dados.shape
# Out:
# (23814, 877)

# %%
# Quando busca-se uma 'label' específica é retornado uma série (nome técnico)
# O objeto .unique() trará as categorias únicas da coluna
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Membrana citoplasmática separa o interior do exterior da célula.
#
# * Dentro o Núcleo o DNA onde carrega toda a estrutura da construção do objeto biológico.

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Gene são trechos/porções do DNA o qual possui a receita para sintetizar uma proteína.
#
# * Para que essa proteína seja sintetizada é necessário um INTERMEDIÁRIO, chamado RNA Mensageiro.
#
# * Essa proteína é sintetizada fora do núcleo

# %%
# Contar a frequência de vezes que aparece o 'objeto'
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
### Desafio 3
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
# Plot Gráfio de pizza

dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
### Selecionar e contar todos os elemenos da classe 'g-0' maiore que zero.
dados_filtrogz = dados[dados['g-0'] > 0]
dados_filtrogz.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ### Desafio 1: Investigar por que a classe tratamento é tão desbalanceada?
#
# ### Desafio 2: Como mostrar as 5 últimos linhas do DataFrame?
#
# * R: Utilizando o objeto .tail()
#
# ### Desafio 3: Proporção das classes tratamento.
#
# * R: Utilizando a função 'normalize = True'
#   dados['tratamento'].value_counts(normalize = True)
#
# ### Desafio 4: Quantas drogas tipos de drogas foi investigados?
#
# ### Desafio 5:  Procurar o método query do Pandas
#
# ### Desafio 6: Colocar título nos gráficos (Matplotlib)
#
# ### Desafio 7: Renomear as Colunas do DataFrame
#
# ### Desafio 8: Resumo do que foi aprendido com os dados

# %% [markdown]
# ## **RESOLUÇÃO DOS DESAFIOS**

# %%
# Desafio 2
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
# Desafio 3
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
# Desafio 7
import re
list_columns = []
for column in dados.columns:
  list_columns.append(re.sub(r'[-]', '_', column))

dados = dados.set_axis(list_columns, axis='columns')
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]
